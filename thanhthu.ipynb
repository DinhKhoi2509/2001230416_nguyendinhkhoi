# %% [markdown]
# <a href="https://colab.research.google.com/github/DinhKhoi2509/2001230416_nguyendinhkhoi/blob/main/thanhthu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%html
# <!DOCTYPE html>
# <html lang="vi">
# <head>
# <meta charset="UTF-8">
# <title>Nước Hoa VERA</title>
#
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@500;700&display=swap" rel="stylesheet">
#
# <style>
# body{
#   margin:0;
#   font-family:'Montserrat',sans-serif;
#   background:#fff0f5;
# }
#
# .header{
#   display:flex;
#   justify-content:space-between;
#   align-items:center;
#   padding:20px;
# }
#
# .tabs{
#   display:flex;
#   gap:12px;
# }
#
# .tab{
#   padding:10px 22px;
#   border-radius:999px;
#   border:2px solid #c2185b;
#   background:#fff;
#   color:#c2185b;
#   font-weight:700;
#   cursor:pointer;
# }
#
# .tab.active{
#   background:#c2185b;
#   color:#fff;
# }
#
# .cart-btn{
#   background:#c2185b;
#   color:#fff;
#   padding:10px 18px;
#   border-radius:999px;
#   font-weight:700;
# }
#
# .product-list{
#   display:grid;
#   grid-template-columns:repeat(auto-fill,minmax(220px,1fr));
#   gap:20px;
#   padding:20px;
# }
#
# .product{
#   background:#fff;
#   border-radius:16px;
#   padding:15px;
#   text-align:center;
#   box-shadow:0 8px 20px rgba(0,0,0,.1);
# }
#
# .product img{
#   width:100%;
#   height:230px;
#   object-fit:cover;
#   border-radius:12px;
# }
#
# .product h3{
#   margin:10px 0 5px;
#   font-size:16px;
# }
#
# .product p{
#   font-size:14px;
#   color:#666;
# }
#
# .price{
#   margin-top:6px;
#   font-weight:700;
#   color:#c2185b;
# }
# </style>
# </head>
#
# <body>
#
# <div class="header">
#   <div class="tabs">
#     <button class="tab active">⭐ TẤT CẢ</button>
#     <button class="tab">🌸 NƯỚC HOA VERA</button>
#   </div>
#   <div class="cart-btn">🛒 Giỏ (0)</div>
# </div>
#
# <div id="product-list" class="product-list"></div>
#
# <script>
# const products = [
#   {id:1,name:"Vera Ruby Edition",price:1200000,image:"images/1.jpg",desc:"Hương hoa quả ngọt ngào"},
#   {id:2,name:"Vera Red Velvet",price:1350000,image:"images/2.jpg",desc:"Quyến rũ, tinh tế"},
#   {id:3,name:"Vera Royal Ruby",price:1500000,image:"images/3.jpg",desc:"Đẳng cấp hoàng gia"},
#   {id:4,name:"Vera Rose Edition",price:1100000,image:"images/4.jpg",desc:"Dịu dàng, nữ tính"},
#   {id:5,name:"Vera Gold Edition",price:1800000,image:"images/5.jpg",desc:"Sang trọng, lưu hương lâu"},
#   {id:6,name:"Vera Silk Touch",price:1600000,image:"images/6.jpg",desc:"Nhẹ nhàng, mượt mà"},
#   {id:7,name:"Vera Fresh Gold",price:1700000,image:"images/7.jpg",desc:"Trái cây tươi mát"},
#   {id:8,name:"Vera Diamond Noir",price:1900000,image:"images/8.jpg",desc:"Huyền bí, quyến rũ"}
# ];
#
# const list = document.getElementById("product-list");
#
# products.forEach(p=>{
#   list.innerHTML += `
#     <div class="product">
#       <img src="${p.image}">
#       <h3>${p.name}</h3>
#       <p>${p.desc}</p>
#       <div class="price">${p.price.toLocaleString()} đ</div>
#     </div>
#   `;
# });
# </script>
#
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="vi">
# <head>
# <meta charset="UTF-8">
# <title>Nước Hoa VERA</title>
#
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@500;700&display=swap" rel="stylesheet">
#
# <style>
# body{
#   margin:0;
#   font-family:'Montserrat',sans-serif;
#   background:#fff0f5;
# }
#
# .header{
#   display:flex;
#   justify-content:space-between;
#   align-items:center;
#   padding:20px;
# }
#
# .tabs{
#   display:flex;
#   gap:12px;
# }
#
# .tab{
#   padding:10px 22px;
#   border-radius:999px;
#   border:2px solid #c2185b;
#   background:#fff;
#   color:#c2185b;
#   font-weight:700;
#   cursor:pointer;
# }
#
# .tab.active{
#   background:#c2185b;
#   color:#fff;
# }
#
# .cart-btn{
#   background:#c2185b;
#   color:#fff;
#   padding:10px 18px;
#   border-radius:999px;
#   font-weight:700;
# }
#
# .product-list{
#   display:grid;
#   grid-template-columns:repeat(auto-fill,minmax(220px,1fr));
#   gap:20px;
#   padding:20px;
# }
#
# .product{
# ...
